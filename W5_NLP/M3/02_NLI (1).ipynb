# %% [markdown]
# ## Natural Language Inference

# %% [markdown]
# Zero-shot classification can also be done using [Natural Language Inference (NLI)](https://nlpprogress.com/english/natural_language_inference.html), which refers to the task of determining, given a "premise" and a "hypothesis", whether the hypothesis is:
#
# - True (**entailment**)
# - False (**contradiction**)
# - Undetermined (**neutral**)

# %% [markdown]
# Example:
#
# | Premise | Hypothesis | Label |
# | --- | --- | --- |
# | A soccer game with multiple males playing. | Some men are playing a sport. | entailment |
# | A man inspects the uniform of a figure in some East Asian country. | The man is sleeping. | contradiction |
# | An older and younger man smiling. | Two men are smiling and laughing at the cats playing on the floor. | neutral |

# %% [markdown]
# NLI (Natural Language Inference) can pull off zero-shot classification by turning the task into a true/false question. Here's how:
# 1. take the text you want to classify (e.g., a movie review) and call it the "premise."
# 2. craft a "hypothesis" like, “This is a positive review.”
# 3. The model checks if this hypothesis follows from the premise (entailment = true) or contradicts it (false).
#     - If it "entails," label it positive;
#     - if it "contradicts," it’s negative.
#
# You don't even need specific training for this.

# %% [markdown]
# Zero, single and few-shot classification seem to be an emergent feature of large language models. This feature seems to come about around model sizes of +100M parameters. The effectiveness of a model at a zero, single or few-shot task seems to scale with model size, meaning that larger models (models with more trainable parameters or layers) generally do better at this task.

# %% [markdown]
# - Approaches used for NLI include earlier symbolic and statistical approaches to more recent deep learning approaches.
# - Benchmark datasets used for NLI include [SNLI](https://paperswithcode.com/dataset/snli), [MultiNLI](https://paperswithcode.com/dataset/multinli), [SciTail](https://paperswithcode.com/dataset/scitail), among others.
# - You can get hands-on practice on the SNLI task by following this [d2l.ai chapter](https://d2l.ai/chapter_natural-language-processing-applications/natural-language-inference-and-dataset.html).

# %% [markdown]
# Let's grab a [NLI model from HuggingFace](https://huggingface.co/models?pipeline_tag=zero-shot-classification) and demonstrate how to use it for zero-shot classification:

# %%
# %pip install -qU datasets transformers[sentencepiece]
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.3/512.3 kB 36.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 104.9 MB/s eta 0:00:00

# %%
from transformers import pipeline

# Pre-trained MNLI model
pipe = pipeline(
    model="facebook/bart-large-mnli",
    device='cuda',
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cuda

# %%
predictions = pipe("I have a problem with my iphone that needs to be resolved asap!",
    candidate_labels=["urgent", "not urgent", "phone", "tablet", "computer"],
)
predictions
# Out:
# {'sequence': 'I have a problem with my iphone that needs to be resolved asap!',
#  'labels': ['urgent', 'phone', 'computer', 'not urgent', 'tablet'],
#  'scores': [0.5227577686309814,
#   0.45814040303230286,
#   0.014264780096709728,
#   0.0026850062422454357,
#   0.0021520727314054966]}

# %% [markdown]
# Let's make it multi-label classification via `multi_labels=True`:

# %%
predictions = pipe("I have a problem with my iphone that needs to be resolved asap!",
    candidate_labels=["urgent", "not urgent", "phone", "tablet", "computer"],
    multi_label=True
)
predictions
# Out:
# {'sequence': 'I have a problem with my iphone that needs to be resolved asap!',
#  'labels': ['urgent', 'phone', 'computer', 'not urgent', 'tablet'],
#  'scores': [0.9987171292304993,
#   0.9945850968360901,
#   0.18989649415016174,
#   0.0007674150983802974,
#   0.0003826087631750852]}

# %% [markdown]
# Let's try running this on the `rotten_tomatoes` dataset (movie reviews):

# %%
import pandas as pd
from datasets import load_dataset

tomatoes = load_dataset("rotten_tomatoes")

# Pandas for easier control
# tomatoes_train_df = pd.DataFrame(tomatoes["train"])
tomatoes_eval_df = pd.DataFrame(tomatoes["test"])
# Out:
# README.md: 0.00B [00:00, ?B/s]
# train.parquet:   0%|          | 0.00/699k [00:00<?, ?B/s]
# validation.parquet:   0%|          | 0.00/90.0k [00:00<?, ?B/s]
# test.parquet:   0%|          | 0.00/92.2k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8530 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1066 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1066 [00:00<?, ? examples/s]

# %%
tomatoes_eval_df
# Out:
#                                                    text  label
# 0     lovingly photographed in the manner of a golde...      1
# 1                 consistently clever and suspenseful .      1
# 2     it's like a " big chill " reunion of the baade...      1
# 3     the story gives ample opportunity for large-sc...      1
# 4                     red dragon " never cuts corners .      1
# ...                                                 ...    ...
# 1061  a terrible movie that some people will neverth...      0
# 1062  there are many definitions of 'time waster' bu...      0
# 1063  as it stands , crocodile hunter has the hurrie...      0
# 1064  the thing looks like a made-for-home-video qui...      0
# 1065  enigma is well-made , but it's just too dry an...      0
#
# [1066 rows x 2 columns]

# %% [markdown]
# It takes 44s to classify all 1,066 examples on a run on T4 GPU:

# %%
# Candidate labels
candidate_labels = [
    "very negative movie review",
    "very positive movie review",
]
candidate_labels_dict = {k: v for k, v in enumerate(candidate_labels)}

# Create predictions
predictions = pipe(tomatoes_eval_df.text.tolist(), candidate_labels)

# %%
predictions
# Out:
# [{'sequence': 'lovingly photographed in the manner of a golden book sprung to life , stuart little 2 manages sweetness largely without stickiness .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9860209822654724, 0.013979016803205013]},
#  {'sequence': 'consistently clever and suspenseful .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9858868718147278, 0.014113093726336956]},
#  {'sequence': 'it\'s like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.5961082577705383, 0.40389180183410645]},
#  {'sequence': 'the story gives ample opportunity for large-scale action and suspense , which director shekhar kapur supplies with tremendous skill .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9758872985839844, 0.024112746119499207]},
#  {'sequence': 'red dragon " never cuts corners .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9044985175132751, 0.09550146758556366]},
#  {'sequence': 'fresnadillo has something serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.7950052618980408, 0.20499473810195923]},
#  {'sequence': 'throws in enough clever and unexpected twists to make the formula feel fresh .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9855634570121765, 0.01443649921566248]},
#  {'sequence': 'weighty and ponderous but every bit as filling as the treat of the title .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.7349390387535095, 0.2650609314441681]},
#  {'sequence': "a real audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9913234114646912, 0.008676608093082905]},
#  {'sequence': 'generates an enormous feeling of empathy for its characters .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9791138172149658, 0.020886151120066643]},
#  {'sequence': "exposing the ways we fool ourselves is one hour photo's real strength .",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0
",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9007971882820129, 0.09920281171798706]},
#  {'sequence': 'skin of man gets a few cheap shocks from its kids-in-peril theatrics , but it also taps into the primal fears of young people trying to cope with the mysterious and brutal nature of adults .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.7927661538124084, 0.20723383128643036]},
#  {'sequence': 'the piano teacher is not an easy film . it forces you to watch people doing unpleasant things to each other and themselves , and it maintains a cool distance from its material that is deliberately unsettling .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9630059003829956, 0.036994144320487976]},
#  {'sequence': 'as refreshing as a drink from a woodland stream .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9346061944961548, 0.0653938427567482]},
#  {'sequence': "williams absolutely nails sy's queasy infatuation and overall strangeness .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.8588190078735352, 0.14118099212646484]},
#  {'sequence': 'can i admit xxx is as deep as a petri dish and as well-characterized as a telephone book but still say it was a guilty pleasure ?',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.5296434760093689, 0.47035646438598633]},
#  {'sequence': "while it's nothing we haven't seen before from murphy , i spy is still fun and enjoyable and so aggressively silly that it's more than a worthwhile effort .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9900215864181519, 0.009978423826396465]},
#  {'sequence': 'by the time it ends in a rush of sequins , flashbulbs , blaring brass and back-stabbing babes , it has said plenty about how show business has infiltrated every corner of society -- and not always for the better .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9168726205825806, 0.08312743902206421]},
#  {'sequence': 'an intimate contemplation of two marvelously messy lives .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.6566734313964844, 0.3433265686035156]},
#  {'sequence': 'rarely has skin looked as beautiful , desirable , even delectable , as it does in trouble every day .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.7900100350379944, 0.20998995006084442]},
#  {'sequence': 'this is one of those rare docs that paints a grand picture of an era and makes the journey feel like a party .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9978145360946655, 0.0021854566875845194]},
#  {'sequence': 'poignant if familiar story of a young person suspended between two cultures .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.8308651447296143, 0.16913482546806335]},
#  {'sequence': 'a metaphor for a modern-day urban china searching for its identity .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.542000949382782, 0.457999050617218]},
#  {'sequence': 'for all its brooding quality , ash wednesday is suspenseful and ultimately unpredictable , with a sterling ensemble cast .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9856542348861694, 0.014345780946314335]},
#  {'sequence': "an odd drama set in the world of lingerie models and bar dancers in the midwest that held my interest precisely because it didn't try to .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9152902364730835, 0.08470973372459412]},
#  {'sequence': 'the film feels uncomfortably real , its language and locations bearing the unmistakable stamp of authority .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8692265748977661, 0.13077346980571747]},
#  {'sequence': 'despite its faults , gangs excels in spectacle and pacing .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9647491574287415, 0.035250838845968246]},
#  {'sequence': 'entertaining despite its one-joke premise with the thesis that women from venus and men from mars can indeed get together .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9638795852661133, 0.03612039238214493]},
#  {'sequence': "a tightly directed , highly professional film that's old-fashioned in all the best possible ways .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9974110722541809, 0.0025889009702950716]},
#  {'sequence': "it's dark but has wonderfully funny moments ; you care about the characters ; and the action and special effects are first-rate .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9853363037109375, 0.014663704670965672]},
#  {'sequence': 'in visual fertility treasure planet rivals the top japanese animations of recent vintage .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.92792147397995, 0.07207851856946945]},
#  {'sequence': 'enormously enjoyable , high-adrenaline documentary .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.998083233833313, 0.0019167565042153]},
#  {'sequence': 'buy is an accomplished actress , and this is a big , juicy role .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9757381677627563, 0.024261880666017532]},
#  {'sequence': "it works its magic with such exuberance and passion that the film's length becomes a part of its fun .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9922292828559875, 0.0077706994488835335]},
#  {'sequence': 'beautifully crafted and brutally honest , promises offers an unexpected window into the complexities of the middle east struggle and into the humanity of its people .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.974073588848114, 0.025926461443305016]},
#  {'sequence': 'an old-fashioned but emotionally stirring adventure tale of the kind they rarely make anymore .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9879075288772583, 0.01209242083132267]},
#  {'sequence': "charlotte sometimes is a gem . it's always enthralling .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9964544177055359, 0.003545617451891303]},
#  {'sequence': 'in my opinion , analyze that is not as funny or entertaining as analyze this , but it is a respectable sequel .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9096593260765076, 0.09034063667058945]},
#  {'sequence': 'a remarkable film by bernard rose .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.993507444858551, 0.006492537911981344]},
#  {'sequence': "zhuangzhuang creates delicate balance of style , text , and subtext that's so simple and precise that anything discordant would topple the balance , but against all odds , nothing does .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.6524177193641663, 0.34758228063583374]},
#  {'sequence': "a much more successful translation than its most famous previous film adaptation , writer-director anthony friedman's similarly updated 1970 british production .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9322330355644226, 0.06776702404022217]},
#  {'sequence': 'an original and highly cerebral examination of the psychopathic mind',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9747027158737183, 0.02529723010957241]},
#  {'sequence': "michel piccoli's moving performance is this films reason for being .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9911816120147705, 0.008818418718874454]},
#  {'sequence': 'a captivating and intimate study about dying and loving . . .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9957650303840637, 0.004234997555613518]},
#  {'sequence': "this is an elegantly balanced movie -- every member of the ensemble has something fascinating to do -- that doesn't reveal even a hint of artifice .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9969794154167175, 0.003020572941750288]},
#  {'sequence': '[grant] goes beyond his usual fluttering and stammering and captures the soul of a man in pain who gradually comes to recognize it and deal with it .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9539620876312256, 0.04603789001703262]},
#  {'sequence': 'a high-spirited buddy movie about the reunion of berlin anarchists who face arrest 15 years after their crime .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9966321587562561, 0.003367897355929017]},
#  {'sequence': "about the best thing you could say about narc is that it's a rock-solid little genre picture . whether you like it or not is basically a matter of taste .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9177530407905579, 0.08224690705537796]},
#  {'sequence': 'an involving , inspirational drama that sometimes falls prey to its sob-story trappings .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.8126128315925598, 0.18738716840744019]},
#  {'sequence': 'some of the most inventive silliness you are likely to witness in a movie theatre for some time .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.8052658438682556, 0.19473418593406677]},
#  {'sequence': "canadian filmmaker gary burns' inventive and mordantly humorous take on the soullessness of work in the city .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.6909309029579163, 0.30906909704208374]},
#  {'sequence': 'a rollicking ride , with jaw-dropping action sequences , striking villains , a gorgeous color palette , astounding technology , stirring music and a boffo last hour that leads up to a strangely sinister happy ending .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9973611235618591, 0.002638851758092642]},
#  {'sequence': "everyone's insecure in lovely and amazing , a poignant and wryly amusing film about mothers , daughters and their relationships .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9947853088378906, 0.005214723292738199]},
#  {'sequence': 'the closest thing to the experience of space travel',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.6105487942695618, 0.38945120573043823]},
#  {'sequence': 'full of surprises .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9201846122741699, 0.0798153504729271]},
#  {'sequence': "connoisseurs of chinese film will be pleased to discover that tian's meticulous talent has not withered during his enforced hiatus .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9708943963050842, 0.0291056577116251]},
#  {'sequence': "if you can push on through the slow spots , you'll be rewarded with some fine acting .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9168733358383179, 0.08312666416168213]},
#  {'sequence': 'an unusually dry-eyed , even analytical approach to material that is generally played for maximum moisture .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.
',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9973849654197693, 0.0026150462217628956]},
#  {'sequence': 'the most consistently funny of the austin powers films .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9857576489448547, 0.01424234826117754]},
#  {'sequence': "ana's journey is not a stereotypical one of self-discovery , as she's already comfortable enough in her own skin to be proud of her rubenesque physique . . .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.7405386567115784, 0.259461373090744]},
#  {'sequence': 'cockettes has the glorious , gaudy benefit of much stock footage of those days , featuring all manner of drag queen , bearded lady and lactating hippie .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.815664529800415, 0.18433547019958496]},
#  {'sequence': "there's something poignant about an artist of 90-plus years taking the effort to share his impressions of life and loss and time and art with us .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.5195261240005493, 0.48047393560409546]},
#  {'sequence': 'the comedy makes social commentary more palatable .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.6491418480873108, 0.35085809230804443]},
#  {'sequence': 'an ideal love story for those intolerant of the more common saccharine genre .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9910949468612671, 0.008905034512281418]},
#  {'sequence': 'one funny popcorn flick .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9800372123718262, 0.01996275596320629]},
#  {'sequence': "this new zealand coming-of-age movie isn't really about anything . when it's this rich and luscious , who cares ?",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9466522932052612, 0.05334767326712608]},
#  {'sequence': 'tully is worth a look for its true-to-life characters , its sensitive acting , its unadorned view of rural life and the subtle direction of first-timer hilary birmingham .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.994759738445282, 0.005240247119218111]},
#  {'sequence': 'this gorgeous epic is guaranteed to lift the spirits of the whole family .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9964368939399719, 0.0035630592610687017]},
#  {'sequence': 'the wild thornberrys movie is pleasant enough and the message of our close ties with animals can certainly not be emphasized enough .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9870515465736389, 0.012948407791554928]},
#  {'sequence': 'williams creates a stunning , taxi driver-esque portrayal of a man teetering on the edge of sanity .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9145877361297607, 0.08541228622198105]},
#  {'sequence': "if you're in the right b-movie frame of mind , it may just scare the pants off you .",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9508213996887207, 0.049178596585989]},
#  {'sequence': 'a movie of riveting power and sadness .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.757560670375824, 0.24243928492069244]},
#  {'sequence': 'both a detective story and a romance spiced with the intrigue of academic skullduggery and politics .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.8258576989173889, 0.1741422563791275]},
#  {'sequence': 'quietly engaging .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9543958306312561, 0.045604169368743896]},
#  {'sequence': 'ludicrous , but director carl franklin adds enough flourishes and freak-outs to make it entertaining .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.5025379061698914, 0.49746206402778625]},
#  {'sequence': "director roger kumble offers just enough sweet and traditional romantic comedy to counter the crudity . and there's the inimitable diaz , holding it all together .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9792647957801819, 0.02073524333536625]},
#  {'sequence': "spielberg's picture is smarter and subtler than [total recall and blade runner] , although its plot may prove too convoluted for fun-seeking summer audiences .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.7978434562683105, 0.20215654373168945]},
#  {'sequence': "it's got all the familiar bruckheimer elements , and schumacher does probably as good a job as anyone at bringing off the hopkins/rock collision of acting styles and onscreen personas .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9727476239204407, 0.02725236490368843]},
#  {'sequence': 'a grittily beautiful film that looks , sounds , and feels more like an extended , open-ended poem than a traditionally structured story .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.933035135269165, 0.06696487218141556]},
#  {'sequence': 'dense , exhilarating documentary .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9949597716331482, 0.005040286108851433]},
#  {'sequence': 'the production values are of the highest and the performances attractive without being memorable .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9854031801223755, 0.014596827328205109]},
#  {'sequence': 'a well-rounded tribute to a man whose achievements -- and complexities -- reached far beyond the end zone .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.
",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.5570931434631348, 0.44290676712989807]},
#  {'sequence': 'whether or not ram dass proves as clear and reliable an authority on that as he was about inner consciousness , fierce grace reassures us that he will once again be an honest and loving one .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.7449008226394653, 0.25509920716285706]},
#  {'sequence': 'sly , sophisticated and surprising .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9591238498687744, 0.04087616503238678]},
#  {'sequence': 'spare but quietly effective retelling .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.7011103630065918, 0.2988896369934082]},
#  {'sequence': 'demonstrates a vivid imagination and an impressive style that result in some terrific setpieces .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9879721403121948, 0.012027877382934093]},
#  {'sequence': 'by its modest , straight-ahead standards , undisputed scores a direct hit .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9592657685279846, 0.04073423519730568]},
#  {'sequence': 'its story about a young chinese woman , ah na , who has come to new york city to replace past tragedy with the american dream is one that any art-house moviegoer is likely to find compelling .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9866328835487366, 0.013367105275392532]},
#  {'sequence': 'for those who like quirky , slightly strange french films , this is a must !',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9720752239227295, 0.0279247984290123]},
#  {'sequence': 'there are so few films about the plight of american indians in modern america that skins comes as a welcome , if downbeat , missive from a forgotten front .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8680267930030823, 0.13197319209575653]},
#  {'sequence': '[shyamalan] continues to cut a swathe through mainstream hollywood , while retaining an integrity and refusing to compromise his vision .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9731345176696777, 0.026865528896450996]},
#  {'sequence': 'a whale of a good time for both children and parents seeking christian-themed fun .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9949097037315369, 0.005090313497930765]},
#  {'sequence': 'what begins as a film in the tradition of the graduate quickly switches into something more recyclable than significant .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9288238883018494, 0.07117608934640884]},
#  {'sequence': 'much smarter and more attentive than it first sets out to be .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.830141544342041, 0.16985847055912018]},
#  {'sequence': 'the story is smart and entirely charming in intent and execution .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.994714617729187, 0.005285391118377447]},
#  {'sequence': 'a movie of technical skill and rare depth of intellect and feeling .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9959403276443481, 0.004059651400893927]},
#  {'sequence': 'represents a worthy departure from the culture clash comedies that have marked an emerging indian american cinema .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9859961271286011, 0.014003858901560307]},
#  {'sequence': "doesn't do more than expand a tv show to movie length . however , it's pleasant enough and its ecological , pro-wildlife sentiments are certainly welcome .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9392960667610168, 0.06070394068956375]},
# ...
#  {'sequence': 'the only fun part of the movie is playing the obvious game . you try to guess the order in which the kids in the house will be gored .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.7927982211112976, 0.20720183849334717]},
#  {'sequence': 'i spied with my little eye . . . a mediocre collection of cookie-cutter action scenes and occasionally inspired dialogue bits',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9366453886032104, 0.06335461884737015]},
#  {'sequence': 'entertains not so much because of its music or comic antics , but through the perverse pleasure of watching disney scrape the bottom of its own cracker barrel .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.5156997442245483, 0.4843002259731293]},
#  {'sequence': 'the satire is just too easy to be genuinely satisfying .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9487197995185852, 0.051280196756124496]},
#  {'sequence': 'bearable . barely .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.6183916926383972, 0.3816083073616028]},
#  {'sequence': 'less funny than it should be and less funny than it thinks it is .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9371880292892456, 0.0628119707107544]},
#  {'sequence': 'an " o bruin , where art thou ? " -style cross-country adventure . . . it has sporadic bursts of liveliness , some so-so slapstick and a few ear-pleasing songs on its soundtrack .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.6335252523422241, 0.3664746582508087]},
#  {'sequence': 'a feeble tootsie knockoff .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8889011144638062, 0.11109889298677444]},
#  {'sequence': 'an awful movie that will only satisfy the most emotionally malleable of filmgoers .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9951770901679993, 0.004822911694645882]},
#  {'sequence': 'the story is far-flung , illogical , and plain stupid .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9859213829040527, 0.014078575186431408]},
#  {'sequence': 'the very simple story seems too simple and the working out of the plot almost arbitrary .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9103172421455383, 0.08968273550271988]},
#  {'sequence': 'an allegory concerning the chronically mixed signals african american professionals get about overachieving could be intriguing , but the supernatural trappings only obscure the message .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.5234914422035217, 0.4765084981918335]},
#  {'sequence': "a very familiar tale , one that's been told by countless filmmakers about italian- , chinese- , irish- , latin- , indian- , russian- and other hyphenate american young men struggling to balance conflicting cultural messages .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.512423574924469, 0.487576425075531]},
#  {'sequence': 'one key problem with these ardently christian storylines is that there is never any question of how things will turn out .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.7794060111045837, 0.22059401869773865]},
#  {'sequence': 'essentially , the film is weak on detail and strong on personality',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9583011269569397, 0.041698820888996124]},
#  {'sequence': 'a relentless , bombastic and ultimately empty world war ii action flick .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9903277158737183, 0.009672211483120918]},
#  {'sequence': "[hell is] looking down at your watch and realizing serving sara isn't even halfway through .",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9338836669921875, 0.06611636281013489]},
#  {'sequence': 'too long , and larded with exposition , this somber cop drama ultimately feels as flat as the scruffy sands of its titular community .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9844942092895508, 0.015505813993513584]},
#  {'sequence': 'leaves viewers out in the cold and undermines some phenomenal performances .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9663701057434082, 0.033629920333623886]},
#  {'sequence': '. . . a ho-hum affair , always watchable yet hardly memorable .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9308473467826843, 0.06915265321731567]},
#  {'sequence': 'swiftly deteriorates into a terribly obvious melodrama and rough-hewn vanity project for lead actress andie macdowell .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9729999899864197, 0.027000028640031815]},
#  {'sequence': 'the histrionic muse still eludes madonna and , playing a charmless witch , she is merely a charmless witch .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8760544657707214, 0.12394554167985916]},
#  {'sequence': 'you have no affinity for most of the characters . nothing about them is attractive . what they see in each other also is difficult to fathom .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.979742705821991, 0.02025727368891239]},
#  {'sequence': 'diaz , applegate , blair and posey are suitably kooky which should appeal to women and they strip down often enough to keep men alert , if not amused .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.8533976078033447, 0.14660237729549408]},
#  {'sequence': 'a technically well-made suspenser . . . but its abrupt drop in iq points as it races to the finish line proves simply too discouraging to let slide .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8242399096488953, 0.17576007544994354]},
#  {'sequence': "an inept , tedious spoof of '70s kung fu pictures , it contains almost enough chuckles for a three-minute sketch , and no more .",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9531396627426147, 0.04686039313673973]},
#  {'sequence': "it's a mystery how the movie could be released in this condition .",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9658591151237488, 0.03414091840386391]},
#  {'sequence': 'absolutely ( and unintentionally ) terrifying .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8157376646995544, 0.18426236510276794]},
#  {'sequence': 'eckstraordinarily lame and severely boring .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9440009593963623, 0.055999044328927994]},
#  {'sequence': 'eight legged freaks falls flat as a spoof .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9465910792350769, 0.05340892821550369]},
#  {'sequence': 'no matter how much he runs around and acts like a doofus , accepting a 50-year-old in the role is creepy in a michael jackson sort of way .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8767108917236328, 0.123289093375206]},
#  {'sequence': "you'll just have your head in your hands wondering why lee's character didn't just go to a bank manager and save everyone the misery .",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9648293256759644, 0.03517066314816475]},
#  {'sequence': "'dragonfly' dwells on crossing-over mumbo jumbo , manipulative sentimentality , and sappy dialogue .",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9816259145736694, 0.01837410032749176]},
#  {'sequence': 'in his determination to lighten the heavy subject matter , silberling also , to a certain extent , trivializes the movie with too many nervous gags and pratfalls .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.7706420421600342, 0.2293579876422882]},
#  {'sequence': 'blade ii has a brilliant director and charismatic star , but it suffers from rampant vampire devaluation .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8537298440933228, 0.14627015590667725]},
#  {'sequence': 'veers uncomfortably close to pro-serb propaganda .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.659460186958313, 0.340539813041687]},
#  {'sequence': 'staggeringly dreadful romance .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9848788976669312, 0.015121103264391422]},
#  {'sequence': 'movies like high crimes flog the dead horse of surprise as if it were an obligation . how about surprising us by trying something new ?',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8626037240028381, 0.13739629089832306]},
#  {'sequence': "final verdict : you've seen it all before .",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.7023849487304688, 0.29761502146720886]},
#  {'sequence': 'throwing in everything except someone pulling the pin from a grenade with his teeth , windtalkers seems to have ransacked every old world war ii movie for overly familiar material .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9636338353157043, 0.03636615350842476]},
#  {'sequence': 'if a few good men told us that we " can\'t handle the truth " than high crimes poetically states at one point in this movie that we " don\'t care about the truth . "',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9409781694412231, 0.05902183800935745]},
#  {'sequence': 'further sad evidence that tom tykwer , director of the resonant and sense-spinning run lola run , has turned out to be a one-trick pony -- a maker of softheaded metaphysical claptrap .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.945885419845581, 0.054114583879709244]},
#  {'sequence': "you'll trudge out of the theater feeling as though you rode the zipper after eating a corn dog and an extra-large cotton candy .",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8122979402542114, 0.18770207464694977]},
#  {'sequence': 'the movie is a little tired ; maybe the original inspiration has run its course .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.938090980052948, 0.06190905719995499]},
#  {'sequence': 'this will go on so long as there are moviegoers anxious to see strange young guys doing strange guy things .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.5637945532798767, 0.4362054765224457]},
#  {'sequence': 'a full-frontal attack on audience patience .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9280527234077454, 0.07194722443819046]},
#  {'sequence': 'any intellectual arguments being made about the nature of god are framed in a drama so clumsy , there is a real danger less sophisticated audiences will mistake it for an endorsement of the very things that bean abhors .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8437060117721558, 0.15629397332668304]},
#  {'sequence': "it's a big idea , but the film itself is small and shriveled .",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9583056569099426, 0.041694339364767075]},
#  {'sequence': 'debut effort by " project greenlight " winner is sappy and amateurish .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9587364792823792, 0.04126347228884697]},
#  {'sequence': "one gets the impression the creators of don't ask don't tell laughed a hell of a lot at their own jokes . too bad none of it is funny .",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8624618053436279, 0.13753817975521088]},
#  {'sequence': 'the cast has a high time , but de broca has little enthusiasm for such antique pulp .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.7878516316413879, 0.21214830875396729]},
#  {'sequence': "the film , like jimmy's routines , could use a few good laughs .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.6435667276382446, 0.35643333196640015]},
#  {'sequence': "the film has too many spots where it's on slippery footing , but is acceptable entertainment for the entire family and one that's especially fit for the kiddies .",
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.7772155404090881, 0.22278444468975067]},
#  {'sequence': 'purports to be a hollywood satire but winds up as the kind of film that should be the target of something deeper and more engaging . oh , and more entertaining , too .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.7595341205596924, 0.24046586453914642]},
#  {'sequence': ". . . in the pile of useless actioners from mtv schmucks who don't know how to tell a story for more than four minutes .",
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9868928790092468, 0.013107063248753548]},
#  {'sequence': 'though it was made with careful attention to detail and is well-acted by james spader and maggie gyllenhaal , i felt disrespected .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.8746219277381897, 0.1253780871629715]},
#  {'sequence': 'well-made but mush-hearted .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.9143080711364746, 0.08569192886352539]},
#  {'sequence': 'humor in i spy is so anemic .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9855464100837708, 0.014453602023422718]},
#  {'sequence': 'the film is strictly routine .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.5579124689102173, 0.4420875906944275]},
#  {'sequence': 'a real snooze .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9283080101013184, 0.07169202715158463]},
#  {'sequence': 'skillful as he is , mr . shyamalan is undone by his pretensions .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.7541863322257996, 0.24581369757652283]},
#  {'sequence': 'while the new film is much more eye-catching than its blood-drenched stephen norrington-directed predecessor , the new script by the returning david s . goyer is much sillier .',
#   'labels': ['very positive movie review', 'very negative movie review'],
#   'scores': [0.8610528111457825, 0.13894720375537872]},
#  {'sequence': 'in addition to sporting one of the worst titles in recent cinematic history , ballistic : ecks vs . sever also features terrible , banal dialogue ; convenient , hole-ridden plotting ; superficial characters and a rather dull , unimaginative car chase .',
#   'labels': ['very negative movie review', 'very positive movie review'],
#   'scores': [0.9937636852264404, 0.006236259825527668]},
#  ...]

# %% [markdown]
# ## Exercise
#
# Identify the user intent using NLI:
#
# - `"Hello, I want to get me a Laptop how much does it cost?"`
#     - `"BUY Laptop"`
# - `"I am very frustrated with your service, and I wanna cancel right now!"`
#     - `"CANCEL Subscription"`
# - `"Here I bought this Keyboard, but it is not working. I want to get my money back!"`
#     - `"REFUND Transaction"`

# %%
# YOUR CODE HERE
# Testing your NLI example
result = pipe(
    "Here I bought this Keyboard, but it is not working. I want to get my money back!",
    candidate_labels=["BUY Laptop", "CANCEL Subscription", "REFUND Transaction"]
)

result
# Out:
# {'sequence': 'Here I bought this Keyboard, but it is not working. I want to get my money back!',
#  'labels': ['REFUND Transaction', 'CANCEL Subscription', 'BUY Laptop'],
#  'scores': [0.8885068297386169, 0.06699260324239731, 0.04450051859021187]}

# %%
result = pipe(
    "I am very frustrated with your service, and I wanna cancel right now!",
    candidate_labels=["BUY Laptop", "CANCEL Subscription", "REFUND Transaction"]
)

result
# Out:
# {'sequence': 'I am very frustrated with your service, and I wanna cancel right now!',
#  'labels': ['CANCEL Subscription', 'REFUND Transaction', 'BUY Laptop'],
#  'scores': [0.8480133414268494, 0.13112331926822662, 0.02086329460144043]}

# %%
result = pipe(
    "Hello, I want to get me a Laptop how much does it cost?",
    candidate_labels=["BUY Laptop", "CANCEL Subscription", "REFUND Transaction"]
)

result
# Out:
# {'sequence': 'Hello, I want to get me a Laptop how much does it cost?',
#  'labels': ['BUY Laptop', 'REFUND Transaction', 'CANCEL Subscription'],
#  'scores': [0.8006560802459717, 0.1742575466632843, 0.025086354464292526]}
